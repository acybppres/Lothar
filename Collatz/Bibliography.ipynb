# %% [markdown]
# # Lagarias' Giant Annotated Bibliography
#
# ```
# @article{lagarias2003annotated1,
#   title={The 3x+1 problem: An annotated bibliography (1963--1999)},
#   author={Lagarias, Jeffrey C.},
#   journal={arXiv preprint math/0309224},
#   year={2003},
#   url={https://arxiv.org/abs/math/0309224}
# }
# ```

# %% [markdown]
# # References of Lagarias 1985 Paper

# %% [markdown]
# ```
# @article{lagarias1985,
#   title={The 3x + 1 problem and its generalizations},
#   author={Lagarias, Jeffrey C.},
#   journal={The American Mathematical Monthly},
#   volume={92},
#   number={1},
#   pages={3--23},
#   year={1985},
#   publisher={Taylor \& Francis}
# }
# ```
#
# Legarias' references:
#
# ##### 1 -- read
#
# ```
# @article{allouche1979,
#   title={Sur la conjecture de "Syracuze-Kakutani-Collatz},
#   author={J.-P. Allouche},
#   journal={Seminaire de Theoris de Nombres},
#   volume={Exp},
#   number={9},
#   pages={15},
#   year={1979},
#   publisher={CNRS, Talence(France)}
#   url={http://eudml.org/doc/182044}
# }
#
# ```
#
# ##### 2
#
# ```
# @article{ando1983,
#   title={letter to J.C. Lagarias, Feb. 18, 1983 Reports that Prof. Nabuo Yoneda (Dept of Information Science, Tokyo Univ. for all n < 2^40 = 1.2x10^12},
#   author={Shiro Ando},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
# ##### 3
# ```
# @article{andree1971,
#   title={Modern Abstract Algebra},
#   author={R.V. Andree},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1971},
#   publisher={Holt, Rheinhart and Winston}
# }
# ```
# ##### 4
# ```
# @article{popcompapr1973_1,
#   title={The 3x + 1 problem},
#   author={},
#   journal={Popular Computing},
#   volume={April 1973},
#   number={},
#   pages={1-2},
#   year={1973},
#   publisher={}
# }
# ```
# ##### 5
# ```
# @article{popcompjul1973,
#   title={The 3x + 1 problem(continued)},
#   author{},
#   journal={Popular Computing},
#   volume={July 1973},
#   number={},
#   pages={6-7},
#   year={1973},
#   publisher={}
# }
# ```
# ##### 6
# ```
# @article{popcompapr1973_2,
#   title={3x + 1 strings},
#   author={},
#   journal={Popular Computing},
#   volume={April 1973},
#   number={},
#   pages={12-13},
#   year={1973},
#   publisher={}
# }
# ```
# ##### 7
# ```
# @article{popcompapr1975,
#   title={3x + 1 once again},
#   author={},
#   journal={Popular Computing},
#   volume={April 1975},
#   number={},
#   pages={4-5},
#   year={1975},
#   publisher={}
# }
# ```
# ##### 8
# ```
# @article{ash1965,
#   title={Information Theory},
#   author={R. Ash},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1965},
#   publisher={Interscience Publishers, Wiley, NY}
# }
# ```
# ##### 9
# ```
# @article{atkin1966,
#   author    = {Atkin, O. L.},
#   title     = {Comment on Problem 63-13},
#   journal   = {SIAM Review},
#   volume    = {8},
#   year      = {1966},
#   pages     = {234--236},
#   doi       = {10.1137/1008050}
# }
# ```
# ##### 10
# ```
# @book{baker1975,
#   author    = {Baker, Alan},
#   title     = {Transcendental Number Theory},
#   publisher = {Cambridge University Press},
#   address   = {London; New York},
#   year      = {1975},
#   isbn      = {0521204615},
#   doi       = {10.1017/CBO9780511565977},
#   url       = {https://doi.org/10.1017/CBO9780511565977}
# }
# ```
# ##### 11 -- read
# ```
# @article{beeler1972,
#   title={HAKMEM Memo 239, Artificial Intelligence Laboratory, M.I.T.},
#   author={M. Beeler, W. Gosper, R. Schroeppel},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1972},
#   publisher={},
#   note={presents some numerical results on cycles for the 3x + 1 related problems}
#   url={https://www.inwap.com/pdp10/hbaker/hakmem/flows.html#item133}
# }
# ```
# ##### 12 (never published)
# ```
# @article{blazewicz1983,
#   title={Collatz's Conjecture and Binary Sequences, Institute of Control Engineering, Technical University of Poznan, Poznan Poland (preprint) March 1983},
#   author={Blazewicz, J., Pettorossi, A.},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1983},
#   publisher={}
# }
# ```
# ##### 13 -- read
# ```
# @article{bohm1978,
#   author    = {B{\"o}hm, Corrado and Sontacchi, Giovanna},
#   title     = {On the existence of cycles of given length in integer sequences like $x_{n+1} = x_n/2$ if $x_n$ is even and $x_{n+1} = 3x_n + 1$ otherwise},
#   journal   = {Atti della Accademia Nazionale dei Lincei. Classe di Scienze Fisiche, Matematiche e Naturali. Rendiconti},
#   volume    = {64},
#   number    = {3},
#   pages     = {260--264},
#   year      = {1978},
#   publisher = {Accademia Nazionale dei Lincei},
#   url       = {http://eudml.org/doc/290184}
# }
# ```
# ##### 14 -- read
# ```
# @book{borevich1966,
#   author       = {Borevich, Z. I. and Shafarevich, I. R.},
#   title        = {Number Theory},
#   publisher    = {Academic Press},
#   address      = {New York, NY},
#   year         = {1966},
#   pages        = {x + 435},
#   isbn         = {0121178501, 9780121178505},
#   note         = {English translation of the 1964 Russian edition; no DOI available},
#   url          = {https://archive.org/details/numbertheory00bore}
# }
# ```
# ##### 15
# ```
# @article{bruce1978,
#   title={Crazy rollercoaster},
#   author{Bruze, M. J.},
#   journal={Math Teacher},
#   volume={71 (January 1978)},
#   number={},
#   pages={45-49},
#   year={1978},
#   publisher={}
# }
# ```
# ##### 16
# ```
# @article{choquet1980_part,
#   author    = {Choquet, Gustave},
#   title     = {Répartition des nombres $k(3/2)^n$},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris},
#   series    = {S{\'e}rie A},
#   volume    = {290},
#   year      = {1980},
#   month     = {March},
#   pages     = {575--580},
# }
# ```
# ##### 17
# ```
# @article{choquet1980_algo,
#   author    = {Choquet, Gustave},
#   title     = {Algorithmes adapt{\'e}s aux suites $(k\theta^n)$ et aux cha{\^\i}nes associ{\'e}es},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie A},
#   volume    = {290},
#   year      = {1980},
#   month     = {April},
#   pages     = {719--724}
# }
# ```
# ##### 18
# ```
# @article{choquet1980_recurs,
#   author    = {Choquet, Gustave},
#   title     = {Jeux r{\'e}cursifs et application aux suites $(k\theta^n)$ ; sol{\'e}no{\"i}des de $\Pi^{\zeta}$},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie A},
#   volume    = {290},
#   year      = {1980},
#   month     = {May},
#   pages     = {863--868}
# }
# ```
# ##### 19
# ```
# @article{choquet1980_construction,
#   author    = {Choquet, Gustave},
#   title     = {Construction effective de suites $k(3/2)^n$. {\'E}tude des mesures $(3/2)$-stables},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie A},
#   volume    = {291},
#   year      = {1980},
#   month     = {September},
#   pages     = {69--74}
# }
# ```
# ##### 20
# ```
# @article{choquet1980_fermes,
#   author    = {Choquet, Gustave},
#   title     = {Les ferm{\'e}s $\theta$-stables de $\Pi$ ; structure des ferm{\'e}s d{\'e}nombrables ; applications arithm{\'e}tiques},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie A},
#   volume    = {291},
#   year      = {1980},
#   month     = {September},
#   pages     = {239--244}
# }
# ```
# ##### 21
# ```
# @article{choquet1981_theta,
#   author    = {Choquet, Gustave},
#   title     = {$\theta$-ferm{\'e}s; $\theta$-cha{\^\i}nes et $\theta$-cycles (pour $\theta = 3/2$)},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie I Math{\'e}matique},
#   volume    = {292},
#   number    = {1},
#   year      = {1981},
#   pages     = {5--10}
# }
# ```
# ##### 22
# ```
# @article{choquet1981_hausdorff,
#   author    = {Choquet, Gustave},
#   title     = {$\theta$-ferm{\'e}s et dimension de Hausdorff; conjectures de travail; arithm{\'e}tique des $\theta$-cycles},
#   journal   = {Comptes Rendus de l'Acad{\'e}mie des Sciences de Paris, S{\'e}rie I Math{\'e}matique},
#   volume    = {292},
#   number    = {3},
#   year      = {1981},
#   pages     = {239--244}
# }
# ```
# ##### 23
# ```
# @article{collatz1976,
#   title={letters to R. Terras May 1976 and 2 Sept. 1976},
#   author={Collatz, Lothar}
# }
# ```
#
#
# ##### 24
# ```
# @article{collatz1980,
#   title={letter to L. Garner, 17 March 1980},
#   author={Collatz, Lothar},
#   note={In none of these letters does L. Collatz actually state that he proposed the $3x+1$ problem}
# }
# ```
#
# ##### 25
# ```
#
# @incollection{collatz1977_verzweigungsdiagramme,
#   author    = {Collatz, Lothar},
#   title     = {Verzweigungsdiagramme und Hypergraphen},
#   booktitle = {Numerik und Anwendungen von Eigenwertaufgaben und Verzweigungsproblemen},
#   series    = {International Series of Numerical Mathematics},
#   volume    = {38},
#   pages     = {9--42},
#   publisher = {Birkh{\"a}user},
#   address   = {Basel},
#   year      = {1977},
#   url       = {https://link.springer.com/chapter/10.1007/978-3-0348-5579-2_1},
#   note      = {This paper remarks on the use graphical representation to study interation problems, as in Fig. 1 in teh text.  Id does not discuss the $3x+1$ problem}
# }
# ```
#
#
# ##### 26
# ```
# @inproceedings{conway1972,
#   author    = {Conway, J. H.},
#   title     = {Unpredictable Iterations},
#   booktitle = {Proceedings of the 1972 Number Theory Conference},
#   address   = {University of Colorado, Boulder},
#   publisher = {University of Colorado},
#   year      = {1972},
#   pages     = {49--52}
# }
# ```
#
# ##### 27
# ```
#
# @article{coxeter1971_cyclic_frieze,
#   author  = {Coxeter, H. S. M.},
#   title   = {Cyclic Sequences and Frieze Patterns: The Fourth Felix Behrend Memorial Lecture},
#   journal = {Vinculum},
#   volume  = {8},
#   pages   = {4--7},
#   year    = {1971},
#   note    = {In this lecture Coxeter offered a \$50 prize for proof of the $3x+1$ Conjecture and \$100 for a counter example, according to C. W. Trigg [67]}
# }
# ```
#
#
# ##### 28 -- read
# ```
# @article{crandall1978,
#   author    = {Crandall, Richard E.},
#   title     = {On the ``3x+1'' Problem},
#   journal   = {Mathematics of Computation},
#   volume    = {32},
#   number    = {144},
#   pages     = {1281--1292},
#   year      = {1978},
#   publisher = {American Mathematical Society},
#   doi       = {10.1090/S0025-5718-1978-0480321-3},
#   url       = {https://www.ams.org/journals/mcom/1978-32-144/S0025-5718-1978-0480321-3/}
# }
# ```
#
# ##### 29
# ```
#
# @inproceedings{davison1977,
#   author    = {Davison, J. L.},
#   title     = {Some Comments on an Iteration Problem},
#   booktitle = {Proceedings of the 6th Manitoba Conference on Numerical Mathematics and Computing},
#   address   = {University of Manitoba, Winnipeg},
#   series    = {Congressus Numerantium},
#   volume    = {XVII},
#   pages     = {155--159},
#   publisher = {Utilitas Mathematica},
#   year      = {1977}
#   note      = {Conference held in 1976}
# }
# ```
#
#
# ##### 30 -- read
# ```
# @techreport{dunn1973_ulam,
#   author      = {Dunn, Richard},
#   title       = {On Ulam's Problem},
#   institution = {Department of Computer Science, University of Colorado},
#   address     = {Boulder, Colorado},
#   number      = {CU-CS-011-73},
#   year        = {1973},
#   month       = jan,
#   url         = {https://apps.dtic.mil/sti/pdfs/ADA447635.pdf}
# }
#
# ```
#
#
# ##### 31 -- read, referenced
# ```
# @article{Everett1977,
#   author    = {C.J. Everett},
#   title     = {Iteration of the Number-Theoretic Function f(2n) = n, f(2n + 1) = 3n + 2},
#   journal   = {Advances in Mathematics},
#   volume    = {25},
#   number    = {},
#   pages     = {42--45},
#   year      = {1977},
#   doi       = {10.1016/0001-8708(77)90087-1}
# }
# ```
#
#
# ##### 32
# ```
# @article{fraenkel1981,
#   title={private communitation 1981},
#   author={Fraenkel, A. S.},
# }
# ```
#
#
# ##### 33
# ```
# @article{gardner1972,
#   author    = {Gardner, Martin},
#   title     = {Mathematical Games},
#   journal   = {Scientific American},
#   volume    = {226},
#   number    = {6},
#   pages     = {114--118},
#   year      = {1972},
#   month     = {June},
#   url       = {https://www.jstor.org/stable/24948701}
# }
# ```
#
#
# ##### 34 -- read, stopping time focused, should cite upper bound based on current largest runs
# ```
# @article{garner1981,
#   author    = {Garner, Lynn E.},
#   title     = {On the Collatz $3n+1$ Algorithm},
#   journal   = {Proceedings of the American Mathematical Society},
#   volume    = {82},
#   number    = {1},
#   pages     = {19--22},
#   year      = {1981},
#   doi       = {10.1090/S0002-9939-1981-0603593-2},
#   url       = {https://www.ams.org/proc/1981-082-01/S0002-9939-1981-0603593-2/},
#   note      = {any cycle not containing 1 must have at least 35,400 terms}
# }
# ```
#
#
# ##### 35 -- read, on programatic solutions dealing with large ints
# ```
#
# @article{gruenberger1979,
#   author    = {Gruenberger, Fred},
#   title     = {The 3×+1 Problem Revisited},
#   journal   = {Popular Computing},
#   volume    = {5},
#   number    = {7},
#   pages     = {3--12},
#   month     = oct,
#   year      = {1979},
#   url       = {https://archive.org/download/Popular_Computing/Popular%20Computing%2079.pdf},
#   note      = {very focused on the computational issues}
# }
# ```
#
#
# ##### 36 -- summarized by CoPilot
# ```
# @book{guy1981,
#   title={Unsolved Problems in Number Theory},
#   author={Guy, R. K.},
#   year={1981},
#   publisher={Springer-Verlag, Ney York},
#   note={Problem E16 is Guy's description of the Collatz conjecture with historical notes and Erdos' famous line “Mathematics may not be ready for such problems.”}
# }
# ```
#
#
# ##### 37 -- non-mathematical
# ```
# @article{guy1983_pulp,
#   title={Don't try to solve these Problems!},
#   author={Guy, R. K.},
#   journal={this MONTHLY},
#   volume={90},
#   pages={35-41},
#   year={1983},
# }
# ```
#
#
# ##### 38
# ```
# @article{guy1983,
#   title={Conway's prime producing machine},
#   author={Guy, R. K.},
#   journal={Mathematics Magazine},
#   volume={56},
#   pages={26-33},
#   year={1983},
# }
# ```
#
#
# ##### 39
# ```
# @article{halmos1956,
#   title={Lectures on Ergodic Theory},
#   author={Halmos, P.},
#   journal={Mathematical Society of Japan, Tokyo},
#   volume={},
#   number={},
#   pages={22-33},
#   year={1956},
#   publisher={}
#  }
# ```
#
#
# ##### 40  -- Copilot agrees that the inite Cycles Conjecture was not ever proven
# ```
# @article{hasse1975,
#   title={Unsolved Problems in Elementary Number Theory, Lectures at U. Maine (Orono), Spring 1975},
#   author={Hasse, H.},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1975},
#   publisher={},
#   note={Dittoed notes.  He states that Thompson has proved the Finite Cycles Conjecture, a result I am unable to verify}
# }
# ```
#
#
# ##### 41 -- Short, read.  A BETTER Version of my initial proof !!!
# ```
#
# @article{heppner1978,
#   author    = {Heppner, E.},
#   title     = {Eine Bemerkung zum Hasse-Syracuse-Algorithmus},
#   journal   = {Archiv der Mathematik},
#   volume    = {31},
#   number    = {},
#   pages     = {317--320},
#   year      = {1978},
#   doi       = {10.1007/BF01226454},
#   url       = {https://link.springer.com/article/10.1007/BF01226454}
# }
# ```
#
# Begins with:
#
# Terse introduction of previous works from Everett, Collatz, Terras, Von H. Hasse, Moller, Beweis
# :
# Then he states:
# Hier soil nun ein recht einfacher Beweis für das folgende scharfere Ergebnis gegeben werden. Wit verwenden dazu ein bekanntes Ergebnis aus der Wahrscheinlich-keitstheorie (Bernsteins Verscharfung der Tschebyscheffschen Ungleichung)
#
# Ands with:
# $$
# T^N(n) \le n(\frac{m + {\epsilon}'}{d})^{N(1-(1/d)+{\epsilon}')}(\frac{1}{d})^{N((1/d) -{\epsilon})} = nK^{N}
# $$
# mit
# $$
# log(K) = (1 - \frac{1}{d} + {\epsilon})log(m + {\epsilon}') - log(d) < 0
# $$
# Hieraus folgt die Behauptung
#
# Summary:
# - Introduces Bernstein’s sharpened Chebyshev inequality
# - Develops tighter-than-mine *statistical* argument for convergence
#
# ##### 42 - just problem description
# ```
# @book{herrstein1978,
#   title={"Matters Mathematical, 2nd edition},
#   author={Herrstein, I. N., Kaplansky, I.},
#   pages={44-45},
#   year={1978},
#   publisher={Chelsea, New York, New York},
#   note={They call the problem the "Syracuse algorithm"}
# }
# ```
#
#
# ##### 43 - just problem description
# ```
# @book{hofstadter1979,
#   title={Godel, Escher, Bach},
#   author={Hofstadter, D},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1979},
#   publisher={Basic Books, New York, New York}
# }
# ```
#
#
# ##### 44 -- variant proposal
# ```
# @article{isard1969,
#   title={Three open questions in the theory of one-symbol Smullyan systems},
#   author=Isard, S. D., Zwicky, A. M. },
#   journal={SIGACT News},
#   volume={},
#   number={},
#   pages={11-14},
#   year={1969},
#   note={They propose the problem let f(n)=n/3 if n=0 mod{3} and let g(n)=2n+1. Can all numbers n=0 or 1 (mod 3) be reduced to 1 by a series of operations f and g? See [67] p.148}
# }
# ```
#
#
# ##### 45 -- Private communication
# ```
# @article{kakutani1981,
#   title={Private communication},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={1981},
#   publisher={}
# }
# ```
#
#
# ##### 46
# ```
# @article{key1972,
#   title={Undergraduate Research Project no. 2},
#   author={},
#   journal={Pi Mu Epsilon J.},
#   volume={338},
#   number={},
#   pages={},
#   year={1972},
#   publisher={}
# }
# ```
#
#
# ##### 47 - variation from 1963
# ```
# @article{klamkin1963,
#   title={Problem 63-12},
#   author={Klamkin, M.S.},
#   journal={SIAM Review},
#   volume={5},
#   pages={275-276},
#   year={1963},
#   note={States the problem: Consider the
# permutation f: N+ --> N' defined by f(3n) = 2n, f(3n - 1) = 4n - 1, f(3n - 2) = 4n - 3. Does n = 8 have an
# infinite trajectory?  How many finite cycles are there for f ? This function was the original one proposed by L. Collatz
# in 1932 [24]}
# }
# ```
#
# ##### 47a -- preprint, published, read
# https://sci-hub.st/10.1016/0022-314X(87)90032-1
# ```
# @article{leigh_matthews_1987,
#   author    = {Leigh, G. M. and Matthews, K. R.},
#   title     = {A generalization of the Syracuse algorithm in $\mathbb{F}_q[x]$},
#   journal   = {Journal of Number Theory},
#   volume    = {25},
#   number    = {3},
#   pages     = {274--278},
#   year      = {1987},
#   doi       = {10.1016/0022-314X(87)90032-1},
#   url       = {https://doi.org/10.1016/0022-314X(87)90032-1}
# }
# ```
#
# ##### 48  -- variant proposal
# ```
# @article{mahler1968,
#   title={An unsolvedproblemon the powers of 3/2},
#   author={Mahler, K.},
#   journal={Austral.Math. Soc.},
#   volume={8},
#   pages={313-321},
#   year={1968},
#   note={ The problem Mahler  studies was originally proposed by Prof.Saburo Uchiyama(Tsukuba Univ.), accordingto S. Ando
# [2]. It arose indirectly in connection with the function g(k) of Waring's problem, see G. H. Harding and E. M.
# Wright, "An Introduction to the Theory of Numbers(4th ed.)", Oxford Univ. Press,1960, Theorem 393ff}
# }
# ```
#
#
# ##### 49 -- Supports section 2.8. "Connections of the 3x + 1 problem to ergodic theory"
# ```
# @book{mahler1976,
#   author    = {Mahler, Kurt},
#   title     = {p-adic Numbers and Their Functions},
#   edition   = {2nd},
#   series    = {Cambridge Tracts in Mathematics},
#   number    = {76},
#   publisher = {Cambridge University Press},
#   year      = {1976},
#   isbn      = {9780521231022}
# }
#
# ```
# ##### 50 -- this is intense, need to read again,
# the url works, wind up at http://matwbn.icm.edu.pl/ksiazki/aa/aa43/aa4327.pdf
#
# ```
# @article{matthews_watts_1984,
#   author    = {Matthews, K. R. and Watts, A. M.},
#   title     = {A generalization of Hasse's generalization of the Syracuse algorithm},
#   journal   = {Acta Arithmetica},
#   volume    = {43},
#   number    = {2},
#   pages     = {167--175},
#   year      = {1984},
#   url       = {https://eudml.org/doc/205897},
#   doi       = {10.4064/aa-43-2-167-175}
# }
# ```
#
#
# ##### 51 -- this is intense, need to read again
# K. R. Matthewsand A. M. Watts,  Markov approach to the generalized Syracuse algorithm
# the url works
# ```
# @article{matthews_watts_1985,
#   author    = {Matthews, K. R. and Watts, A. M.},
#   title     = {A Markov approach to the generalized Syracuse algorithm},
#   journal   = {Acta Arithmetica},
#   volume    = {45},
#   number    = {1},
#   pages     = {29--42},
#   year      = {1985},
#   url       = {https://eudml.org/doc/205953}
# }
# ```
#
# ##### 51a --
# K. R. Matthews and A. M. Watts,  Some invariant probability measures on the polyadic numbers
# ```
# @article{matthews_watts_1985,
#   author    = {Matthews, K. R. and Watts, A. M.},
#   title     = {Some invariant probability measures on the polyadic numbers (preprint},
# }
#
# Likely a later version that subsumed the above (but which in turn identifies itself as a continuation of the following BibTex entry:
#
# @article{matthews_1992_borel,
#   author    = {Matthews, K. R.},
#   title     = {Some Borel measures associated with the generalized Collatz mapping},
#   journal   = {Colloquium Mathematicae},
#   volume    = {63},
#   number    = {2},
#   pages     = {191--202},
#   year      = {1992},
#   url       = {https://eudml.org/doc/210145}
# }
# continuation-of:
#
# @article{buttsworth_matthews_1990,
#   author    = {Buttsworth, R. N. and Matthews, K. R.},
#   title     = {On some Markov matrices arising from the generalized Collatz mapping},
#   journal   = {Acta Arithmetica},
#   volume    = {55},
#   number    = {1},
#   pages     = {43--57},
#   year      = {1990},
#   url       = {https://eudml.org/doc/210145}
# }
#
# ```
#
#
# ##### 52
# URL works
#
# Lararias' note:
# This paperclaimsA. Fraenkelcheckedthatf(k)(n) = 1 forall n < 250,a resultin error[32]. In
# a note added in proofit assertstheproofsof Terras[64] are faulty.They seemessentiallycorrectto me,and Terras
# [65] supplieselided details.
#
# CoPilot summary:
#
# # **Summary of the Key Points**
#
# Möller’s paper sits at an important point in the early theoretical development of generalized Collatz‑type mappings. The work extends and clarifies ideas first proposed by **H. Hasse** in the 1960s–70s regarding generalizations of the *Syracuse algorithm* (the Collatz function) to modular partitions more complex than the 2‑adic splitting *even/odd*.
#
# Below are the core contributions of the paper.
#
# ***
#
# ## **1. Möller formalizes Hasse’s generalization of the Syracuse (3n+1) algorithm**
#
# Hasse had introduced a broad class of Collatz‑like transformations of the form:
#
# *   Partition the integers into residue classes modulo **d**.
# *   For each residue class, apply a linear transformation
#     $$
#     T(n) = \frac{m_i n - r_i}{d},
#     $$
#     where the choice of $$m_i$$, $$r_i$$ depends on the class $$n \bmod d$$.
#
# This includes the classical Collatz map
#
# $$
# T(n)=\begin{cases}n/2, & n\equiv0\pmod2 \\ (3n+1)/2, & n\equiv1\pmod2\end{cases}
# $$
#
# as the special case $$d=2$$.
# Möller codifies the full structure of these transformations and gives a definitive formulation of Hasse’s generalization.    [\[jstor.org\]](https://www.jstor.org/stable/44166344)
#
# ***
#
# ## **2. The paper analyzes structural constraints on the mapping**
#
# Möller establishes necessary modular arithmetic conditions ensuring that:
#
# *   the mapping is **well‑defined** on the integers,
# *   the function maps integers → integers (no fractional outputs), and
# *   iterates remain within the integer lattice.
#
# These structural constraints are crucial for constructing valid generalized Collatz mappings.
#
# ***
#
# ## **3. Möller studies periodic cycles under the generalized map**
#
# One of the key problems Hasse posed was:
#
# > **Do nontrivial cycles exist in these generalized systems, and how can they be characterized?**
#
# Möller analyzes the possible existence of:
#
# *   **pure cycles** (closed orbits),
# *   their lengths, and
# *   algebraic criteria determining whether cycles can arise.
#
# He derives explicit **congruence‑based conditions** that candidate cycles must satisfy, significantly refining Hasse’s earlier heuristic arguments.    [\[jstor.org\]](https://www.jstor.org/stable/44166344)
#
# ***
#
# ## **4. He establishes finiteness conditions for possible cycles**
#
# Using algebraic arguments, Möller proves that:
#
# *   for fixed parameters $$m_i$$, $$r_i$$, and modulus $$d$$,
# *   **only finitely many cycles** can exist.
#
# This finiteness result is the precursor to later finiteness conjectures such as the “finite cycles conjecture” for general Collatz mappings.
#
# ***
#
# ## **5. Möller connects the generalized algorithm to Kakutani’s problem**
#
# The subtitle of the paper—**“Kakutanis Problem”**—refers to Kakutani’s earlier investigations of:
#
# *   measure‑theoretic behavior,
# *   ergodic properties, and
# *   random iterations of linear forms.
#
# Möller shows that Hasse’s generalization fits naturally into the Kakutani framework and discusses implications for:
#
# *   iteration growth rates,
# *   distribution among residue classes, and
# *   the possibility of divergent orbits.
#
# This is an early bridge between Collatz‑type recurrence theory and **ergodic / measure‑theoretic ideas**.
#
# ***
#
# ## **6. The paper provides explicit examples and counterexamples**
#
# Möller constructs:
#
# *   specific parameter families where cycles exist,
# *   others where cycles **cannot** exist,
# *   and explicit examples illustrating the boundary between bounded and unbounded trajectories.
#
# These examples became foundational for later work by Terras, Matthews–Watts, and Buttsworth–Matthews.
#
# ***
#
# # **Why this paper matters**
#
# Möller’s 1978 article is historically important because it:
#
# *   Provides the **first rigorous treatment** of Hasse’s generalized Collatz systems.
# *   Establishes the **modular‑arithmetic backbone** required for further theoretical development.
# *   Influences subsequent work on Markov‑matrix methods, polyadic integers, and invariant measures.
# *   Becomes a standard reference in later Syracuse / Collatz generalizations (cited by Heppner, Matthews, Terras, etc.).
#
# It is one of the earliest papers to treat the Collatz problem not as an isolated curiosity but as part of a **broader algebraic and dynamical family of maps**.
#
# ***
#
# If you want, I can also:
#
# *   give a deeper technical breakdown of Möller’s proofs,
# *   show how Möller’s work connects to Heppner (1978), Terras (1976–79), and Matthews–Watts (1984–1992), or
# *   reconstruct the generalized map $$T$$ exactly as Möller defines it.
#
# ```
#
# @article{moeller1978,
#   author    = {M{\"o}ller, Herbert},
#   title     = {{\"U}ber Hasses Verallgemeinerung des Syracuse-Algorithmus (Kakutanis Problem)},
#   journal   = {Acta Arithmetica},
#   volume    = {34},
#   number    = {3},
#   pages     = {219--226},
#   year      = {1978},
#   url       = {https://eudml.org/doc/205606}
# }
#
# ```
#
#
# ##### 53
#
#  hey discuss the problem of checking the 3x + 1 Conjecture fo ra given n
# and give some interesting empirical observations.
#
# ```
#
# @book{nievergelt_farrar_reingold_1974,
#   author    = {Nievergelt, J{\"u}rg and Farrar, J. Craig and Reingold, Edward M.},
#   title     = {Computer Approaches to Mathematical Problems},
#   publisher = {Prentice-Hall},
#   address   = {Englewood Cliffs, NJ},
#   year      = {1974},
#   pages     = {211--217},
#   isbn      = {0131648551},
#   url       = {https://archive.org/details/computerapproach0000niev}
# }
#
# ```
#
#
# ##### 54
# ```
# @article{ __54__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 55
# ```
# @article{ __55__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 56
# ```
# @article{ __56__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 57
# ```
# @article{ __57__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 58
# ```
# @article{ __58__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 59
# ```
# @article{ __59__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 60
# ```
# @article{ __60__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 61
# ```
# @article{ __61__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 62
# ```
# @article{ __62__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 63
# ```
# @article{ __63__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 64
# ```
# @article{ __64__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 65
# ```
# @article{ __65__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 66
# ```
# @article{ __66__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 67
# ```
# @article{ __67__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 68
# ```
# @article{ __68__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 69
# ```
# @article{ __69__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 70
# ```
# @article{ __70__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```

# %% [markdown]
# DOI format ... add to pages item:
# DOI:10.1899/15-9834.6

# %% [markdown]
# # The 3x+1 problem: An annotated bibliography (1963--1999)
# '''
# @article{lagarias2003annotated1,
#   title={The 3x+1 problem: An annotated bibliography (1963--1999)},
#   author={Lagarias, Jeffrey C.},
#   journal={arXiv preprint math/0309224},
#   year={2003},
#   url={https://arxiv.org/abs/math/0309224}
# }
# '''

# %% [markdown]
# # Another halluicinated negative Collatz article, but good overview from 1975
# ```
# @article{Wagon1985Collatz,
#   author  = {Wagon, Stan},
#   title   = {The Collatz Problem},
#   journal = {The Mathematical Intelligencer},
#   year    = {1985},
#   volume  = {7},
#   number  = {1},
#   pages   = {66--68},
#   doi     = {10.1007/BF03023011}
# }
# ```

# %% [markdown]
# ## 2.2 Behavior of the stopping time function
#
# It is Riho Terras's ingenious observation that although the behavior of the total stopping time function seems hard to analyze, a great deal can be said about the stopping time function.  He proved the fundamental result (\[64\], \[64\]), also found independently by Everrett \[31\].

# %%
for i in range(23, 71, 1):
    fstr = f"""
##### {i}
```
@article{{ __{i}__,
  title={{}},
  author={{}},
  journal={{}},
  volume={{}},
  number={{}},
  pages={{}},
  year={{}},
  publisher={{}}
}}
```
    """
    print(fstr)
# Out:
# ##### 23
# ```
# @article{ __23__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 24
# ```
# @article{ __24__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 25
# ```
# @article{ __25__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 26
# ```
# @article{ __26__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 27
# ```
# @article{ __27__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
#   publisher={}
# }
# ```
#
#
# ##### 28
# ```
# @article{ __28__,
#   title={},
#   author={},
#   journal={},
#   volume={},
#   number={},
#   pages={},
#   year={},
# ...
